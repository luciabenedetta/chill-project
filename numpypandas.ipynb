# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
advertising = pd.read_csv('https://raw.githubusercontent.com/vincenzorrei/EDU-Datasets/refs/heads/main/Advertising.csv', usecols=[1,2,3,4])

# %%
advertising.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
pippo = pd.read_csv('https://raw.githubusercontent.com/vincenzorrei/EDU-Datasets/refs/heads/main/Credit.csv')

# %%
print(type(pippo))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
pippo.head(10) #le prime 10 righe
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
# 5           6   80.180   8047     569      4   77         10    Male      No
# 6           7   20.996   3388     259      2   37         12  Female      No
# 7           8   71.408   7114     512      2   87          9    Male      No
# 8           9   15.125   3300     266      5   66         13  Female      No
# 9          10   71.061   6819     491      3   41         19  Female     Yes
#
#   Married         Ethnicity  Balance
# 0     Yes         Caucasian      333
# 1     Yes             Asian      903
# ...
